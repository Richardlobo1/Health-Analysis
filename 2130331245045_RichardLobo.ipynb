# %% [markdown]
# # Practical Examination Machine Learning 2024

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Q1)

# %% [markdown]
# a)

# %% [markdown]
# b)

# %% [markdown]
# c)

# %% [markdown]
# d)

# %% [markdown]
# f)

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# # Q2)

# %% [markdown]
# a)

# %% [markdown]
# b)

# %% [markdown]
# c)

# %% [markdown]
# d)

# %% [markdown]
# e)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Q3)

# %% [markdown]
# a)

# %% [markdown]
# b)

# %% [markdown]
# c)

# %% [markdown]
# d)

# %% [markdown]
# e)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Q4)

# %% [markdown]
# a)

# %% [markdown]
# b)

# %% [markdown]
# c)

# %% [markdown]
# # Q5)
